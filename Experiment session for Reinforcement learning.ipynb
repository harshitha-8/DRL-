# %%
# !pip install tensorflow==2.3.0
# !pip install gym
# !pip install keras
# !pip install keras-rl2
# Out:
# Requirement already satisfied: tensorflow==2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (2.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.18.5)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: scipy==1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (2.5.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (3.17.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.12.1)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.36.2)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.38.1)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.3.3)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.3.0) (0.13.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (52.0.0.post20210125)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.32.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.1)
# Requirement already satisfied: gym in /opt/anaconda3/lib/python3.8/site-packages (0.18.3)
# Requirement already satisfied: Pillow<=8.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from gym) (8.2.0)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from gym) (1.5.15)
# Requirement already satisfied: numpy>=1.10.4 in /opt/anaconda3/lib/python3.8/site-packages (from gym) (1.18.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from gym) (1.6.0)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.8/site-packages (from gym) (1.4.1)
# Requirement already satisfied: keras in /opt/anaconda3/lib/python3.8/site-packages (2.4.3)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.8/site-packages (from keras) (5.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /opt/anaconda3/lib/python3.8/site-packages (from keras) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /opt/anaconda3/lib/python3.8/site-packages (from keras) (1.4.1)
# Requirement already satisfied: h5py in /opt/anaconda3/lib/python3.8/site-packages (from keras) (2.10.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from h5py->keras) (1.15.0)
# Requirement already satisfied: keras-rl2 in /opt/anaconda3/lib/python3.8/site-packages (1.0.5)
# Requirement already satisfied: tensorflow in /opt/anaconda3/lib/python3.8/site-packages (from keras-rl2) (2.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (0.13.0)
# Requirement already satisfied: wheel>=0.26 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (0.36.2)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.1.2)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (2.5.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.38.1)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.12.1)
# Requirement already satisfied: google-pasta>=0.1.8 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (2.3.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.15.0)
# Requirement already satisfied: scipy==1.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.4.1)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.1.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.18.5)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (3.17.3)
# Requirement already satisfied: astunparse==1.6.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: gast==0.3.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorflow->keras-rl2) (0.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (1.32.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (52.0.0.post20210125)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/anaconda3/lib/python3.8/site-packages (from tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (2020.12.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow->keras-rl2) (3.1.1)

# %%
import gym
import random

# %%
env = gym.make("CartPole-v1")
states = env.observation_space.shape[0]
actions = env.action_space.n

# %%
states
# Out:
# 4

# %%
episodes = 10
for episode in range (1, episodes+1):
    state = env.reset()
    done =False
    score = 0
    
    while not done:
        env.render()
        action = random.choice([0,1])
        n_state, reward,done, info=env.step(action)
        score += reward
        print('episodes:{} score:{}' .format(episode, score))
# Out:
# episodes:1 score:1.0
# episodes:1 score:2.0
# episodes:1 score:3.0
# episodes:1 score:4.0
# episodes:1 score:5.0
# episodes:1 score:6.0
# episodes:1 score:7.0
# episodes:1 score:8.0
# episodes:1 score:9.0
# episodes:1 score:10.0
# episodes:1 score:11.0
# episodes:1 score:12.0
# episodes:1 score:13.0
# episodes:1 score:14.0
# episodes:1 score:15.0
# episodes:2 score:1.0
# episodes:2 score:2.0
# episodes:2 score:3.0
# episodes:2 score:4.0
# episodes:2 score:5.0
# episodes:2 score:6.0
# episodes:2 score:7.0
# episodes:2 score:8.0
# episodes:2 score:9.0
# episodes:2 score:10.0
# episodes:2 score:11.0
# episodes:2 score:12.0
# episodes:2 score:13.0
# episodes:2 score:14.0
# episodes:2 score:15.0
# episodes:2 score:16.0
# episodes:2 score:17.0
# episodes:2 score:18.0
# episodes:2 score:19.0
# episodes:2 score:20.0
# episodes:2 score:21.0
# episodes:2 score:22.0
# episodes:2 score:23.0
# episodes:2 score:24.0
# episodes:2 score:25.0
# episodes:2 score:26.0
# episodes:2 score:27.0
# episodes:2 score:28.0
# episodes:2 score:29.0
# episodes:2 score:30.0
# episodes:2 score:31.0
# episodes:2 score:32.0
# episodes:2 score:33.0
# episodes:3 score:1.0
# episodes:3 score:2.0
# episodes:3 score:3.0
# episodes:3 score:4.0
# episodes:3 score:5.0
# episodes:3 score:6.0
# episodes:3 score:7.0
# episodes:3 score:8.0
# episodes:3 score:9.0
# episodes:7 score:28.0
# episodes:7 score:29.0
# episodes:7 score:30.0
# episodes:7 score:31.0
# episodes:7 score:32.0
# episodes:7 score:33.0
# episodes:7 score:34.0
# episodes:7 score:35.0
# episodes:7 score:36.0
# episodes:7 score:37.0
# episodes:7 score:38.0
# episodes:7 score:39.0
# episodes:7 score:40.0
# episodes:7 score:41.0
# episodes:7 score:42.0
# episodes:8 score:1.0
# episodes:8 score:2.0
# episodes:8 score:3.0
# episodes:8 score:4.0
# episodes:8 score:5.0
# episodes:8 score:6.0
# episodes:8 score:7.0
# episodes:8 score:8.0
# episodes:8 score:9.0
# episodes:8 score:10.0
# episodes:8 score:11.0
# episodes:8 score:12.0
# episodes:8 score:13.0
# episodes:8 score:14.0
# episodes:8 score:15.0
# episodes:8 score:16.0
# episodes:8 score:17.0
# episodes:8 score:18.0
# episodes:8 score:19.0
# episodes:8 score:20.0
# episodes:8 score:21.0
# episodes:8 score:22.0
# episodes:8 score:23.0
# episodes:8 score:24.0
# episodes:8 score:25.0
# episodes:8 score:26.0
# episodes:8 score:27.0
# episodes:8 score:28.0
# episodes:8 score:29.0
# episodes:8 score:30.0
# episodes:8 score:31.0
# episodes:8 score:32.0
# episodes:8 score:33.0
# episodes:8 score:34.0
# episodes:8 score:35.0
# episodes:8 score:36.0
# episodes:8 score:37.0
# episodes:8 score:38.0
# episodes:9 score:1.0
# episodes:9 score:2.0
# episodes:9 score:3.0
# episodes:9 score:4.0
# episodes:9 score:5.0
# episodes:9 score:6.0
# episodes:9 score:7.0
# episodes:9 score:8.0
# episodes:9 score:9.0
# episodes:9 score:10.0
# episodes:9 score:11.0
# episodes:9 score:12.0
# episodes:10 score:1.0
# episodes:10 score:2.0
# episodes:10 score:3.0
# episodes:10 score:4.0
# episodes:10 score:5.0
# episodes:10 score:6.0
# episodes:10 score:7.0
# episodes:10 score:8.0
# episodes:10 score:9.0
# episodes:10 score:10.0
# episodes:10 score:11.0
# episodes:10 score:12.0

# %% [markdown]
# # creating the deep learning model.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
def build_model (states, actions):
    model = Sequential()
    model.add(Flatten(input_shape=(1, states)))
    model.add(Dense(24,activation='relu'))
    model.add(Dense(24, activation= 'relu'))
    model.add(Dense(actions,activation='linear'))
    return model

# %%
model = build_model(states, actions)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 4)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Bulid agents using rl2

# %%
from rl.agents import DQNAgent
from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy = policy,
                   nb_actions = actions, nb_steps_warmup=10, target_model_update = 1e-2)
    return dqn

# %%
def build_agent(model, actions):
    policy = BoltzmannQPolicy()
    #model = tensorflow.keras.Sequential()
    memory = SequentialMemory(limit=50000, window_length=1)
    dqn = DQNAgent(model=model, memory=memory, policy=policy, 
                  nb_actions=actions, nb_steps_warmup=10, target_model_update=1e-2)
    return dqn




dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])
dqn.fit(env, nb_steps=50000, visualize=False, verbose=1)
# Out:
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
#     1/10000 [..............................] - ETA: 16:22 - reward: 1.0000
# /opt/anaconda3/lib/python3.8/site-packages/rl/memory.py:37: UserWarning: Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!
#   warnings.warn('Not enough entries to sample without replacement. Consider increasing your warm-up phase to avoid oversampling!')
# 10000/10000 [==============================] - 79s 8ms/step - reward: 1.0000
# 97 episodes - episode_reward: 102.918 [10.000, 359.000] - loss: 4.626 - mae: 20.584 - mean_q: 41.568
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 95s 10ms/step - reward: 1.0000 0s - reward: 1.0
# 40 episodes - episode_reward: 244.375 [189.000, 325.000] - loss: 5.910 - mae: 44.515 - mean_q: 89.983
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 109s 11ms/step - reward: 1.0000
# 40 episodes - episode_reward: 253.450 [189.000, 393.000] - loss: 4.230 - mae: 50.602 - mean_q: 102.148
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 87s 9ms/step - reward: 1.0000
# 40 episodes - episode_reward: 252.050 [187.000, 371.000] - loss: 3.087 - mae: 50.117 - mean_q: 100.973
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 101s 10ms/step - reward: 1.0000
# done, took 471.405 seconds

# %%
scores = dqn.test(env, nb_episodes=100, visualize=False)
print(np.mean(scores.history['episode_reward']))
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: 232.000, steps: 232
# Episode 2: reward: 229.000, steps: 229
# Episode 3: reward: 286.000, steps: 286
# Episode 4: reward: 302.000, steps: 302
# Episode 5: reward: 253.000, steps: 253
# Episode 6: reward: 215.000, steps: 215
# Episode 7: reward: 240.000, steps: 240
# Episode 8: reward: 244.000, steps: 244
# Episode 9: reward: 207.000, steps: 207
# Episode 10: reward: 286.000, steps: 286
# Episode 11: reward: 254.000, steps: 254
# Episode 12: reward: 204.000, steps: 204
# Episode 13: reward: 219.000, steps: 219
# Episode 14: reward: 221.000, steps: 221
# Episode 15: reward: 247.000, steps: 247
# Episode 16: reward: 280.000, steps: 280
# Episode 17: reward: 268.000, steps: 268
# Episode 18: reward: 216.000, steps: 216
# Episode 19: reward: 320.000, steps: 320
# Episode 20: reward: 257.000, steps: 257
# Episode 21: reward: 264.000, steps: 264
# Episode 22: reward: 355.000, steps: 355
# Episode 23: reward: 243.000, steps: 243
# Episode 24: reward: 214.000, steps: 214
# Episode 25: reward: 225.000, steps: 225
# Episode 26: reward: 231.000, steps: 231
# Episode 27: reward: 228.000, steps: 228
# Episode 28: reward: 260.000, steps: 260
# Episode 29: reward: 207.000, steps: 207
# Episode 30: reward: 279.000, steps: 279
# Episode 31: reward: 225.000, steps: 225
# Episode 32: reward: 226.000, steps: 226
# Episode 33: reward: 218.000, steps: 218
# Episode 34: reward: 211.000, steps: 211
# Episode 35: reward: 276.000, steps: 276
# Episode 36: reward: 274.000, steps: 274
# Episode 37: reward: 213.000, steps: 213
# Episode 38: reward: 197.000, steps: 197
# Episode 39: reward: 271.000, steps: 271
# Episode 40: reward: 272.000, steps: 272
# Episode 41: reward: 241.000, steps: 241
# Episode 42: reward: 305.000, steps: 305
# Episode 43: reward: 208.000, steps: 208
# Episode 44: reward: 249.000, steps: 249
# Episode 45: reward: 221.000, steps: 221
# Episode 46: reward: 211.000, steps: 211
# Episode 47: reward: 304.000, steps: 304
# Episode 48: reward: 229.000, steps: 229
# Episode 49: reward: 207.000, steps: 207
# Episode 50: reward: 239.000, steps: 239
# Episode 51: reward: 203.000, steps: 203
# Episode 52: reward: 284.000, steps: 284
# Episode 53: reward: 251.000, steps: 251
# Episode 54: reward: 228.000, steps: 228
# Episode 55: reward: 272.000, steps: 272
# Episode 56: reward: 240.000, steps: 240
# Episode 57: reward: 215.000, steps: 215
# Episode 58: reward: 215.000, steps: 215
# Episode 59: reward: 222.000, steps: 222
# Episode 60: reward: 268.000, steps: 268
# Episode 61: reward: 217.000, steps: 217
# Episode 62: reward: 333.000, steps: 333
# Episode 63: reward: 219.000, steps: 219
# Episode 64: reward: 302.000, steps: 302
# Episode 65: reward: 216.000, steps: 216
# Episode 66: reward: 239.000, steps: 239
# Episode 67: reward: 276.000, steps: 276
# Episode 68: reward: 265.000, steps: 265
# Episode 69: reward: 237.000, steps: 237
# Episode 70: reward: 223.000, steps: 223
# Episode 71: reward: 245.000, steps: 245
# Episode 72: reward: 217.000, steps: 217
# Episode 73: reward: 231.000, steps: 231
# Episode 74: reward: 238.000, steps: 238
# Episode 75: reward: 273.000, steps: 273
# Episode 76: reward: 223.000, steps: 223
# Episode 77: reward: 217.000, steps: 217
# Episode 78: reward: 234.000, steps: 234
# Episode 79: reward: 207.000, steps: 207
# Episode 80: reward: 261.000, steps: 261
# Episode 81: reward: 238.000, steps: 238
# Episode 82: reward: 221.000, steps: 221
# Episode 83: reward: 324.000, steps: 324
# Episode 84: reward: 260.000, steps: 260
# Episode 85: reward: 217.000, steps: 217
# Episode 86: reward: 240.000, steps: 240
# Episode 87: reward: 283.000, steps: 283
# Episode 88: reward: 282.000, steps: 282
# Episode 89: reward: 282.000, steps: 282
# Episode 90: reward: 269.000, steps: 269
# Episode 91: reward: 211.000, steps: 211
# Episode 92: reward: 261.000, steps: 261
# Episode 93: reward: 273.000, steps: 273
# Episode 94: reward: 222.000, steps: 222
# Episode 95: reward: 209.000, steps: 209
# Episode 96: reward: 328.000, steps: 328
# Episode 97: reward: 248.000, steps: 248
# Episode 98: reward: 250.000, steps: 250
# Episode 99: reward: 284.000, steps: 284
# Episode 100: reward: 209.000, steps: 209
# 246.65

# %%
_ = dqn.test(env, nb_episodes=15, visualize=True)
# Out:
# Testing for 15 episodes ...
# Episode 1: reward: 241.000, steps: 241
# Episode 2: reward: 213.000, steps: 213
# Episode 3: reward: 236.000, steps: 236
# Episode 4: reward: 265.000, steps: 265
# Episode 5: reward: 242.000, steps: 242
# Episode 6: reward: 302.000, steps: 302
# Episode 7: reward: 342.000, steps: 342
# Episode 8: reward: 204.000, steps: 204
# Episode 9: reward: 236.000, steps: 236
# Episode 10: reward: 242.000, steps: 242
# Episode 11: reward: 235.000, steps: 235
# Episode 12: reward: 307.000, steps: 307
# Episode 13: reward: 260.000, steps: 260
# Episode 14: reward: 235.000, steps: 235
# Episode 15: reward: 233.000, steps: 233

# %% [markdown]
# # 4. Reloading Agent from Memory¶

# %%
dqn.save_weights('dqn_weights.h5f', overwrite=True)

# %%
del model
del dqn
del env

# %%
env = gym.make('CartPole-v0')
actions = env.action_space.n
states = env.observation_space.shape[0]
model = build_model(states, actions)
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])

# %%
dqn.load_weights('dqn_weights.h5f')

# %%
_ = dqn.test(env, nb_episodes=5, visualize=True)
# Out:
# Testing for 5 episodes ...
# Episode 1: reward: 200.000, steps: 200
# Episode 2: reward: 200.000, steps: 200
# Episode 3: reward: 200.000, steps: 200
# Episode 4: reward: 200.000, steps: 200
# Episode 5: reward: 200.000, steps: 200
